# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import models.black_cox as bc
V = 120
sigma_V =0.2
r = 0.05
a = 0.01
D = 100
C = 90
gamma = 0.02
T = 1.0

bc.debt_value(V, sigma_V, r, T, D, C, gamma, t=0.0, a=a)
# Out:
# np.float64(93.88271776008119)

# %%
import numpy as np

from utils.plotting import plot_function_vs_param

fig = plot_function_vs_param(
    bc.credit_spread,
    x_param="T",
    x_values=np.linspace(0, 10, 100),
    base_params={
        "V": 120,
        "r": 0.05,
        "sigma_V": 0.2,
        "a": 0.01,
        "D": 100,
        "C": 90,
        "gamma": 0.02,
    },
    y_title="s(T)",
    varying_param="C",
    varying_values=[1, 50, 70, 90, 100],
    title="Credit spread"
)

fig.show()
