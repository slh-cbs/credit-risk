# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
import models.merton as merton
from utils.plotting import plot_function_vs_param
import numpy as np

# %%
fig = plot_function_vs_param(
    merton.equity_value,
    x_param="V",
    x_values=np.linspace(50, 200),
    base_params={
        "D": 100,
        "r": 0.02,
        "T": 1
    },
    y_title="E(V)",
    varying_param="sigma_V",
    varying_values=[0.2, 0.3, 0.4],
    title="Equity value"
)

fig.show()

# %%
fig = plot_function_vs_param(
    merton.credit_spread,
    x_param="T",
    x_values=np.linspace(0, 5, 100),
    base_params={
        "D": 100,
        "r": 0.02,
        "sigma_V": 0.3
    },
    y_title="s(T)",
    varying_param="V",
    varying_values=[110, 125],
    title="Credit spread"
)

fig.show()
